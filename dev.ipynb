# %%
import pandas as pd
import geopandas as gpd
import glob
import os

import rasterio
from rasterio.features import shapes
from shapely.geometry import shape



# Get all tif files from data directory, rename to forward slash paths
raster_files =  glob.glob('./data/*.tif')
raster_files_named = []
for raster_file in raster_files:
    raster_files_named.append(raster_file.replace('\\','/'))
print(', '.join(raster_files_named))

# The name for each output shp file corresponding to each processed tif.
output_files = ['100yr Existing Depth Dissolved.shp','100yr Prop1 Depth Dissolved.shp', '10yr Existing Depth Dissolved.shp',
                '10yr Prop1 Depth Dissolved.shp', '2yr Existing Depth Dissolved.shp','2yr Prop1 Depth Dissolved.shp',]
# Out:
# ./data/100yrExistingWSE (Max) WP.2018_Terrain.2018_1m.tif, ./data/100yrProposed1WSE (Max) WP.2018_Terrain.2018_1m.tif, ./data/10yrExistingWSE (Max) WP.2018_Terrain.2018_1m.tif, ./data/10yrProposed1WSE (Max) WP.2018_Terrain.2018_1m.tif, ./data/2yrExistingWSE (Max) WP.2018_Terrain.2018_1m.tif, ./data/2yrProposed1WSE (Max) WP.2018_Terrain.2018_1m.tif

# %%
# build dataframe of inputs and outputs
df = pd.DataFrame(columns=['raster_file', 'output_file'], data=zip(raster_files_named, output_files))
df
# Out:
#                                          raster_file  \
# 0  ./data\100yrExistingWSE (Max) WP.2018_Terrain....
# 1  ./data\100yrProposed1WSE (Max) WP.2018_Terrain...
# 2  ./data\10yrExistingWSE (Max) WP.2018_Terrain.2...
# 3  ./data\10yrProposed1WSE (Max) WP.2018_Terrain....
# 4  ./data\2yrExistingWSE (Max) WP.2018_Terrain.20...
# 5  ./data\2yrProposed1WSE (Max) WP.2018_Terrain.2...
#
#                           output_file
# 0  100yr Existing Depth Dissolved.shp
# 1     100yr Prop1 Depth Dissolved.shp
# 2   10yr Existing Depth Dissolved.shp
# 3      10yr Prop1 Depth Dissolved.shp
# 4    2yr Existing Depth Dissolved.shp
# 5       2yr Prop1 Depth Dissolved.shp

# %%
# For each row in the dataframe, convert the raster to a shapefile using rasterio, dissolve the shapefile using geopandas, and save the output to the output directory.
for index, row in df.iterrows():
    print(row['raster_file'], row['output_file'])
    with rasterio.open(row['raster_file']) as src:
        data = src.read(1, masked=True)

        # Use a generator instead of a list
        shape_gen = ((shape(s), v) for s, v in shapes(data, transform=src.transform))

        # build a DataFrames from the shape generator
        shape_df = pd.DataFrame(shape_gen, columns=['geometry', 'class'])
        gdf = gpd.GeoDataFrame(shape_df["class"], geometry=shape_df.geometry, crs=src.crs)
    
    # dissolve the shapefile to a single polygon
    dissolved_gdf = gdf.dissolve()
    dissolved_gdf.to_file(f"./output/{row['output_file']}")
# Out:
# ./data\100yrExistingWSE (Max) WP.2018_Terrain.2018_1m.tif 100yr Existing Depth Dissolved.shp
# ./data\100yrProposed1WSE (Max) WP.2018_Terrain.2018_1m.tif 100yr Prop1 Depth Dissolved.shp
# ./data\10yrExistingWSE (Max) WP.2018_Terrain.2018_1m.tif 10yr Existing Depth Dissolved.shp
# ./data\10yrProposed1WSE (Max) WP.2018_Terrain.2018_1m.tif 10yr Prop1 Depth Dissolved.shp
# ./data\2yrExistingWSE (Max) WP.2018_Terrain.2018_1m.tif 2yr Existing Depth Dissolved.shp
# ./data\2yrProposed1WSE (Max) WP.2018_Terrain.2018_1m.tif 2yr Prop1 Depth Dissolved.shp

# %%
with rasterio.open(df['raster_file'][0]) as src:
    data = src.read(1, masked=True)

    # Use a generator instead of a list
    shape_gen = ((shape(s), v) for s, v in shapes(data, transform=src.transform))

    # build a DataFrames from the shape generator
    shape_df = pd.DataFrame(shape_gen, columns=['geometry', 'class'])
    gdf = gpd.GeoDataFrame(shape_df["class"], geometry=shape_df.geometry, crs=src.crs)
dissolved_gdf = gdf.dissolve()
dissolved_gdf.to_file(f"./output/{df['output_file'][0]}")
# Out:
# <Axes: >

# %%
dissolved_gdf.plot()
# Out:
# <Axes: >

# %%
dissolved_gdf.to_file(f"./output/{df['output_file'][0].split('.')[0]}.geojson", driver='GeoJSON')
